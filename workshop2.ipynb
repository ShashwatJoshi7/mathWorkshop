# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashwatJoshi7/mathWorkshop/blob/main/workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
xccxhj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_735/1610459952.py in <cell line: 0>()
# ----> 1 xccxhj
#
# NameError: name 'xccxhj' is not defined
